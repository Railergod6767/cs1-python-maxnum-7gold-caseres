# %% [markdown]
# <a href="https://colab.research.google.com/github/Railergod6767/cs1-python-maxnum-7gold-caseres/blob/main/maxnum.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
    num1 = float(input("Enter the first number: "))
    num2 = float(input("Enter the second number: "))
    num3 = float(input("Enter the third number: "))


    biggest = max(num1, num2, num3)


    print(f"\nOf the numbers {num1}, {num2}, and {num3}...")
    print(f"The biggest one is: {biggest}")
# Out:
# Enter the first number: 5
# Enter the second number: 2
# Enter the third number: 9
#
# Of the numbers 5.0, 2.0, and 9.0...
# The biggest one is: 9.0
